# %%
import pandas as pd

data = pd.read_csv("combined_data.csv")
data
# Out:
#                     Country  \
# United States 1.0      $692
# China         2.0      $440
# India         3.0     $2317
# United States 4.0      $573
# Indonesia     5.0      $332
# ...                     ...
# San Marino    194.0   $1161
# Palau         195.0    $709
# Nauru         196.0    $564
# Tuvalu        197.0    $869
# Vatican       NaN       NaN
#
#                                                                   Rank  \
# United States 1.0                                        New York City
# China         2.0                                              London
# India         3.0                                              Beijing
# United States 4.0    TokyoJapan   Population  14M     Cost of livin...
# Indonesia     5.0                                             Shanghai
# ...                                                                ...
# San Marino    194.0                                                NaN
# ...
